# %% [markdown]
# <a href="https://colab.research.google.com/github/KizMan-23/naural_language/blob/master/bitcoin_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import os

# %%
btc_ticker = yf.Ticker("BTC-USD")

# %%
btc = btc_ticker.history(period="max")

# %%
btc
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2024-10-31 00:00:00+00:00  72335.046875  72662.312500  69590.500000
# 2024-11-01 00:00:00+00:00  70216.898438  71559.015625  68779.703125
# 2024-11-02 00:00:00+00:00  69486.023438  69867.351562  69033.718750
# 2024-11-03 00:00:00+00:00  69296.382812  69361.656250  67482.523438
# 2024-11-04 00:00:00+00:00  68746.789062  69324.906250  67330.523438
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# ...

# %%
btc.dtypes
# Out:
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# dtype: object

# %%
btc.index = pd.to_datetime(btc.index)

# %%
del btc['Dividends']
del btc['Stock Splits']

# %%
btc.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
wiki = pd.read_csv("wikipedia_edits.csv", index_col=0, parse_dates=True)
